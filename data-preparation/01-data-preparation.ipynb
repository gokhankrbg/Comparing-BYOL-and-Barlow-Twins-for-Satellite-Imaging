# %%
# !pip install zarr -q
# !pip install plotly -q
# !pip install seaborn -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.4/205.4 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 77.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.7/53.7 kB 2.6 MB/s eta 0:00:00

# %%
# ==============================================================================
# SSL4EO-S12 DATA DOWNLOAD SCRIPT (ADAPTED FOR KAGGLE)
# ==============================================================================
# Target: 20GB of S2RGB data only (3-channel RGB composite).
# Change: Removed Google Drive check. Using Kaggle's /kaggle/working/
#         directory for persistent storage.
# ==============================================================================

import requests
from pathlib import Path
import time

# --- 1. Configuration ---
# Set the desired modality (S2RGB) and the download limit.
LIMIT_GB = 19
MODALITY_S2L1C = False
MODALITY_S2L2A = False
MODALITY_S1GRD = False
MODALITY_S2RGB = True  # Download this only: 3-channel RGB images.

# Convert limit to bytes and define base directory structure.
LIMIT_BYTES = LIMIT_GB * 1024 * 1024 * 1024
SPLIT = "train"
BASE_DIR = "data/ssl4eo-s12" # This structure will be created inside /kaggle/working/

print("Configuration:")
print(f"   LIMIT_GB: {LIMIT_GB}")
print(f"   MODALITY_S2RGB: {MODALITY_S2RGB}")
print(f"   SPLIT: {SPLIT}")


# --- 2. Functions ---

def setup_directories():
    """
    Creates the directory structure for the Kaggle environment.
    Data is saved to the persistent /kaggle/working/ directory.
    """
    # In Kaggle, the persistent storage location is /kaggle/working/.
    base_dir = Path(f"/kaggle/working/{BASE_DIR}/{SPLIT}")
    storage_type = "Kaggle working directory (persistent across sessions)"

    print(f"\nStorage Type: {storage_type}")
    print(f"Data Location: {base_dir}")

    return base_dir

def download_modality(modality, base_dir):
    """Downloads the specified modality from the web."""

    url_base = f"https://datapub.fz-juelich.de/ssl4eo-s12/{SPLIT}/{modality}"
    target_dir = base_dir / modality
    target_dir.mkdir(parents=True, exist_ok=True)

    print(f"\nDownloading modality: {modality}")
    print(f"   Source URL: {url_base}")
    print(f"   Target Dir: {target_dir}")

    downloaded_count = 0
    total_size = 0

    # Check for existing files and their sizes before starting the download.
    existing_files = list(target_dir.glob("*.zarr.zip"))
    if existing_files:
        existing_size = sum(f.stat().st_size for f in existing_files)
        total_size += existing_size
        downloaded_count = len(existing_files)
        print(f"   Found existing files: {downloaded_count} files, size: {existing_size/1e6:.1f} MB")

    # Download files by iterating through a sequence of file indices.
    # Use a wide range; the script will continue if a 404 error occurs.
    for i in range(1, 500):
        file_name = f"ssl4eos12_{SPLIT}_seasonal_data_{i:06d}.zarr.zip"
        url = f"{url_base}/{file_name}"
        file_path = target_dir / file_name

        # Skip the file if it already exists.
        if file_path.exists():
            continue

        try:
            print(f"   Fetching: {file_name} ...", end='')
            response = requests.get(url, timeout=30, stream=True)

            if response.status_code == 200:
                # Write the file in chunks to use memory efficiently.
                with open(file_path, 'wb') as f:
                    for chunk in response.iter_content(chunk_size=8192):
                        f.write(chunk)

                # Update counters.
                file_size = file_path.stat().st_size
                total_size += file_size
                downloaded_count += 1
                total_mb = total_size / 1e6
                print(f" Done! Total downloaded so far: {total_mb:.1f} MB")

                # Check the download limit.
                if total_size >= LIMIT_BYTES:
                    print(f"\nReached download limit of {LIMIT_GB} GB. Stopping.")
                    break
            
            elif response.status_code == 404:
                # A 404 error is expected if a file doesn't exist on the server; silently skip.
                print(" Not found, trying next.")
                continue # Try the next file.
            
            else:
                print(f" HTTP Error {response.status_code} for {file_name}")
                continue

        except Exception as e:
            print(f"   Error downloading {file_name}: {e}")
            continue

    final_mb = total_size / 1e6
    print(f"\nFinished downloading for modality: {modality}")
    print(f"   Total files for this modality: {downloaded_count}")
    print(f"   Total size for this modality: {final_mb:.1f} MB ({final_mb/1024:.2f} GB)")

    return downloaded_count, total_size

def main():
    """Main execution function."""
    print("\nStarting data acquisition process...")
    start_time = time.time()

    # 1. Prepare directories.
    base_dir = setup_directories()

    total_downloaded_files = 0
    total_size_bytes = 0

    # 2. Download selected modalities.
    if MODALITY_S2RGB:
        count, size = download_modality("S2RGB", base_dir)
        total_downloaded_files += count
        total_size_bytes += size

    # Inform the user why other modalities are being skipped.
    if MODALITY_S2L1C: print("\n(S2L1C disabled in configuration, skipping)")
    if MODALITY_S2L2A: print("(S2L2A disabled, using 3-channel RGB composite instead)")
    if MODALITY_S1GRD: print("(S1GRD disabled, skipping SAR data)")

    # 3. Summarize the results.
    duration_min = (time.time() - start_time) / 60
    final_gb = total_size_bytes / 1e9

    print("\n" + "="*60)
    print(f"DOWNLOAD COMPLETE!")
    print(f"   Final Data Location: {base_dir}")
    print(f"   Total Files Downloaded: {total_downloaded_files}")
    print(f"   Total Size on Disk: {final_gb:.2f} GB")
    print(f"   Total Duration: {duration_min:.1f} minutes")
    print(f"\nData is ready for the next step: Creating a PyTorch Dataset.")
    print("="*60)

    return base_dir, final_gb


# --- 3. Run the Script ---
# This block triggers the main() function when the script is run directly.
# This conditional is often not strictly necessary in a notebook but is good practice.
if __name__ == "__main__":
    save_location, dataset_size = main()

    # Store the data path in a variable for use in subsequent cells.
    S2RGB_DATA_PATH = save_location / "S2RGB"
    print(f"\nPath to S2RGB data for next steps: {S2RGB_DATA_PATH}")
# Out:
# Configuration:
#    LIMIT_GB: 19
#    MODALITY_S2RGB: True
#    SPLIT: train
#
# Starting data acquisition process...
#
# Storage Type: Kaggle working directory (persistent across sessions)
# Data Location: /kaggle/working/data/ssl4eo-s12/train
#
# Downloading modality: S2RGB
#    Source URL: https://datapub.fz-juelich.de/ssl4eo-s12/train/S2RGB
#    Target Dir: /kaggle/working/data/ssl4eo-s12/train/S2RGB
#    Fetching: ssl4eos12_train_seasonal_data_000001.zarr.zip ... Done! Total downloaded so far: 43.0 MB
#    Fetching: ssl4eos12_train_seasonal_data_000002.zarr.zip ... Done! Total downloaded so far: 85.6 MB
#    Fetching: ssl4eos12_train_seasonal_data_000003.zarr.zip ... Done! Total downloaded so far: 126.7 MB
#    Fetching: ssl4eos12_train_seasonal_data_000004.zarr.zip ... Done! Total downloaded so far: 168.3 MB
#    Fetching: ssl4eos12_train_seasonal_data_000005.zarr.zip ... Done! Total downloaded so far: 209.9 MB
#    Fetching: ssl4eos12_train_seasonal_data_000006.zarr.zip ... Done! Total downloaded so far: 252.3 MB
#    Fetching: ssl4eos12_train_seasonal_data_000007.zarr.zip ... Done! Total downloaded so far: 294.9 MB
#    Fetching: ssl4eos12_train_seasonal_data_000008.zarr.zip ... Done! Total downloaded so far: 335.7 MB
#    Fetching: ssl4eos12_train_seasonal_data_000009.zarr.zip ... Done! Total downloaded so far: 379.6 MB
#    Fetching: ssl4eos12_train_seasonal_data_000010.zarr.zip ... Done! Total downloaded so far: 421.8 MB
#    Fetching: ssl4eos12_train_seasonal_data_000011.zarr.zip ... Done! Total downloaded so far: 464.2 MB
#    Fetching: ssl4eos12_train_seasonal_data_
5 MB
#    Fetching: ssl4eos12_train_seasonal_data_000395.zarr.zip ... Done! Total downloaded so far: 16711.9 MB
#    Fetching: ssl4eos12_train_seasonal_data_000396.zarr.zip ... Done! Total downloaded so far: 16754.2 MB
#    Fetching: ssl4eos12_train_seasonal_data_000397.zarr.zip ... Done! Total downloaded so far: 16797.5 MB
#    Fetching: ssl4eos12_train_seasonal_data_000398.zarr.zip ... Done! Total downloaded so far: 16839.8 MB
#    Fetching: ssl4eos12_train_seasonal_data_000399.zarr.zip ... Done! Total downloaded so far: 16882.8 MB
#    Fetching: ssl4eos12_train_seasonal_data_000400.zarr.zip ... Done! Total downloaded so far: 16924.2 MB
#    Fetching: ssl4eos12_train_seasonal_data_000401.zarr.zip ... Done! Total downloaded so far: 16966.7 MB
#    Fetching: ssl4eos12_train_seasonal_data_000402.zarr.zip ... Done! Total downloaded so far: 17009.2 MB
#    Fetching: ssl4eos12_train_seasonal_data_000403.zarr.zip ... Done! Total downloaded so far: 17051.2 MB
#    Fetching: ssl4eos12_train_seasonal_data_000404.zarr.zip ... Done! Total downloaded so far: 17094.9 MB
#    Fetching: ssl4eos12_train_seasonal_data_000405.zarr.zip ... Done! Total downloaded so far: 17136.5 MB
#    Fetching: ssl4eos12_train_seasonal_data_000406.zarr.zip ... Done! Total downloaded so far: 17178.5 MB
#    Fetching: ssl4eos12_train_seasonal_data_000407.zarr.zip ... Done! Total downloaded so far: 17221.1 MB
#    Fetching: ssl4eos12_train_seasonal_data_000408.zarr.zip ... Done! Total downloaded so far: 17264.6 MB
#    Fetching: ssl4eos12_train_seasonal_data_000409.zarr.zip ... Done! Total downloaded so far: 17307.2 MB
#    Fetching: ssl4eos12_train_seasonal_data_000410.zarr.zip ... Done! Total downloaded so far: 17349.4 MB
#    Fetching: ssl4eos12_train_seasonal_data_000411.zarr.zip ... Done! Total downloaded so far: 17392.0 MB
#    Fetching: ssl4eos12_train_seasonal_data_000412.zarr.zip ... Done! Total downloaded so far: 17434.5 MB
#    Fetching: ssl4eos12_train_seasonal_data_000413.zarr.zip ... Done! Total downloaded so far: 17476.7 MB
#    Fetching: ssl4eos12_train_seasonal_data_000414.zarr.zip ... Done! Total downloaded so far: 17519.0 MB
#    Fetching: ssl4eos12_train_seasonal_data_000415.zarr.zip ... Done! Total downloaded so far: 17559.0 MB
#    Fetching: ssl4eos12_train_seasonal_data_000416.zarr.zip ... Done! Total downloaded so far: 17601.2 MB
#    Fetching: ssl4eos12_train_seasonal_data_000417.zarr.zip ... Done! Total downloaded so far: 17644.2 MB
#    Fetching: ssl4eos12_train_seasonal_data_000418.zarr.zip ... Done! Total downloaded so far: 17687.3 MB
#    Fetching: ssl4eos12_train_seasonal_data_000419.zarr.zip ... Done! Total downloaded so far: 17729.1 MB
#    Fetching: ssl4eos12_train_seasonal_data_000420.zarr.zip ... Done! Total downloaded so far: 17771.2 MB
#    Fetching: ssl4eos12_train_seasonal_data_000421.zarr.zip ... Done! Total downloaded so far: 17813.4 MB
#    Fetching: ssl4eos12_train_seasonal_data_000422.zarr.zip ... Done! Total downloaded so far: 17855.3 MB
#    Fetching: ssl4eos12_train_seasonal_data_000423.zarr.zip ... Done! Total downloaded so far: 17897.4 MB
#    Fetching: ssl4eos12_train_seasonal_data_000424.zarr.zip ... Done! Total downloaded so far: 17940.9 MB
#    Fetching: ssl4eos12_train_seasonal_data_000425.zarr.zip ... Done! Total downloaded so far: 17983.4 MB
#    Fetching: ssl4eos12_train_seasonal_data_000426.zarr.zip ... Done! Total downloaded so far: 18026.1 MB
#    Fetching: ssl4eos12_train_seasonal_data_000427.zarr.zip ... Done! Total downloaded so far: 18068.7 MB
#    Fetching: ssl4eos12_train_seasonal_data_000428.zarr.zip ... Done! Total downloaded so far: 18111.8 MB
#    Fetching: ssl4eos12_train_seasonal_data_000429.zarr.zip ... Done! Total downloaded so far: 18154.0 MB
#    Fetching: ssl4eos12_train_seasonal_data_000430.zarr.zip ... Done! Total downloaded so far: 18197.4 MB
#    Fetching: ssl4eos12_train_seasonal_data_000431.zarr.zip ... Done! Total downloaded so far: 18239.0 MB
#    Fetching: ssl4eos12_train_seasonal_data_000432.zarr.zip ... Done! Total downloaded so far: 18281.2 MB
#    Fetching: ssl4eos12_train_seasonal_data_000433.zarr.zip ... Done! Total downloaded so far: 18324.1 MB
#    Fetching: ssl4eos12_train_seasonal_data_000434.zarr.zip ... Done! Total downloaded so far: 18365.8 MB
#    Fetching: ssl4eos12_train_seasonal_data_000435.zarr.zip ... Done! Total downloaded so far: 18408.5 MB
#    Fetching: ssl4eos12_train_seasonal_data_000436.zarr.zip ... Done! Total downloaded so far: 18450.6 MB
#    Fetching: ssl4eos12_train_seasonal_data_000437.zarr.zip ... Done! Total downloaded so far: 18492.9 MB
#    Fetching: ssl4eos12_train_seasonal_data_000438.zarr.zip ... Done! Total downloaded so far: 18533.9 MB
#    Fetching: ssl4eos12_train_seasonal_data_000439.zarr.zip ... Done! Total downloaded so far: 18576.0 MB
#    Fetching: ssl4eos12_train_seasonal_data_000440.zarr.zip ... Done! Total downloaded so far: 18618.5 MB
#    Fetching: ssl4eos12_train_seasonal_data_000441.zarr.zip ... Done! Total downloaded so far: 18662.4 MB
#    Fetching: ssl4eos12_train_seasonal_data_000442.zarr.zip ... Done! Total downloaded so far: 18704.3 MB
#    Fetching: ssl4eos12_train_seasonal_data_000443.zarr.zip ... Done! Total downloaded so far: 18746.1 MB
#    Fetching: ssl4eos12_train_seasonal_data_000444.zarr.zip ... Done! Total downloaded so far: 18788.4 MB
#    Fetching: ssl4eos12_train_seasonal_data_000445.zarr.zip ... Done! Total downloaded so far: 18830.3 MB
#    Fetching: ssl4eos12_train_seasonal_data_000446.zarr.zip ... Done! Total downloaded so far: 18872.6 MB
#    Fetching: ssl4eos12_train_seasonal_data_000447.zarr.zip ... Done! Total downloaded so far: 18914.6 MB
#    Fetching: ssl4eos12_train_seasonal_data_000448.zarr.zip ... Done! Total downloaded so far: 18957.2 MB
#    Fetching: ssl4eos12_train_seasonal_data_000449.zarr.zip ... Done! Total downloaded so far: 19000.2 MB
#    Fetching: ssl4eos12_train_seasonal_data_000450.zarr.zip ... Done! Total downloaded so far: 19043.1 MB
#    Fetching: ssl4eos12_train_seasonal_data_000451.zarr.zip ... Done! Total downloaded so far: 19084.7 MB
#    Fetching: ssl4eos12_train_seasonal_data_000452.zarr.zip ... Done! Total downloaded so far: 19127.1 MB
#    Fetching: ssl4eos12_train_seasonal_data_000453.zarr.zip ... Done! Total downloaded so far: 19168.9 MB
#    Fetching: ssl4eos12_train_seasonal_data_000454.zarr.zip ... Done! Total downloaded so far: 19211.2 MB
#    Fetching: ssl4eos12_train_seasonal_data_000455.zarr.zip ... Done! Total downloaded so far: 19252.8 MB
#    Fetching: ssl4eos12_train_seasonal_data_000456.zarr.zip ... Done! Total downloaded so far: 19294.5 MB
#    Fetching: ssl4eos12_train_seasonal_data_000457.zarr.zip ... Done! Total downloaded so far: 19335.8 MB
#    Fetching: ssl4eos12_train_seasonal_data_000458.zarr.zip ... Done! Total downloaded so far: 19377.8 MB
#    Fetching: ssl4eos12_train_seasonal_data_000459.zarr.zip ... Done! Total downloaded so far: 19420.5 MB
#    Fetching: ssl4eos12_train_seasonal_data_000460.zarr.zip ... Done! Total downloaded so far: 19462.7 MB
#    Fetching: ssl4eos12_train_seasonal_data_000461.zarr.zip ... Done! Total downloaded so far: 19505.1 MB
#    Fetching: ssl4eos12_train_seasonal_data_000462.zarr.zip ... Done! Total downloaded so far: 19546.0 MB
#    Fetching: ssl4eos12_train_seasonal_data_000463.zarr.zip ... Done! Total downloaded so far: 19587.2 MB
#    Fetching: ssl4eos12_train_seasonal_data_000464.zarr.zip ... Done! Total downloaded so far: 19630.5 MB
#    Fetching: ssl4eos12_train_seasonal_data_000465.zarr.zip ... Done! Total downloaded so far: 19672.9 MB
#    Fetching: ssl4eos12_train_seasonal_data_000466.zarr.zip ... Done! Total downloaded so far: 19715.0 MB
#    Fetching: ssl4eos12_train_seasonal_data_000467.zarr.zip ... Done! Total downloaded so far: 19757.4 MB
#    Fetching: ssl4eos12_train_seasonal_data_000468.zarr.zip ... Done! Total downloaded so far: 19801.3 MB
#    Fetching: ssl4eos12_train_seasonal_data_000469.zarr.zip ... Done! Total downloaded so far: 19842.2 MB
#    Fetching: ssl4eos12_train_seasonal_data_000470.zarr.zip ... Done! Total downloaded so far: 19883.7 MB
#    Fetching: ssl4eos12_train_seasonal_data_000471.zarr.zip ... Done! Total downloaded so far: 19926.2 MB
#    Fetching: ssl4eos12_train_seasonal_data_000472.zarr.zip ... Done! Total downloaded so far: 19969.3 MB
#    Fetching: ssl4eos12_train_seasonal_data_000473.zarr.zip ... Done! Total downloaded so far: 20012.5 MB
#    Fetching: ssl4eos12_train_seasonal_data_000474.zarr.zip ... Done! Total downloaded so far: 20055.4 MB
#    Fetching: ssl4eos12_train_seasonal_data_000475.zarr.zip ... Done! Total downloaded so far: 20097.9 MB
#    Fetching: ssl4eos12_train_seasonal_data_000476.zarr.zip ... Done! Total downloaded so far: 20140.0 MB
#    Fetching: ssl4eos12_train_seasonal_data_000477.zarr.zip ... Done! Total downloaded so far: 20181.5 MB
#    Fetching: ssl4eos12_train_seasonal_data_000478.zarr.zip ... Done! Total downloaded so far: 20223.0 MB
#    Fetching: ssl4eos12_train_seasonal_data_000479.zarr.zip ... Done! Total downloaded so far: 20263.9 MB
#    Fetching: ssl4eos12_train_seasonal_data_000480.zarr.zip ... Done! Total downloaded so far: 20306.7 MB
#    Fetching: ssl4eos12_train_seasonal_data_000481.zarr.zip ... Done! Total downloaded so far: 20349.1 MB
#    Fetching: ssl4eos12_train_seasonal_data_000482.zarr.zip ... Done! Total downloaded so far: 20391.2 MB
#    Fetching: ssl4eos12_train_seasonal_data_000483.zarr.zip ... Done! Total downloaded so far: 20432.6 MB
#
# Reached download limit of 19 GB. Stopping.
#
# Finished downloading for modality: S2RGB
#    Total files for this modality: 483
#    Total size for this modality: 20432.6 MB (19.95 GB)
#
# ============================================================
# DOWNLOAD COMPLETE!
#    Final Data Location: /kaggle/working/data/ssl4eo-s12/train
#    Total Files Downloaded: 483
#    Total Size on Disk: 20.43 GB
#    Total Duration: 32.2 minutes
#
# Data is ready for the next step: Creating a PyTorch Dataset.
# ============================================================
#
# Path to S2RGB data for next steps: /kaggle/working/data/ssl4eo-s12/train/S2RGB
